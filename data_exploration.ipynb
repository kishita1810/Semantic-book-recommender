# %% [markdown]
# ### Step 1: Download the dataset from Kaggle using the kagglehub library

# %%
#!pip install kagglehub
# Out:
# ...
#   Using cached kagglehub-0.3.10-py3-none-any.whl.metadata (31 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached kagglehub-0.3.10-py3-none-any.whl (63 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.47M/1.47M [00:00<00:00, 7.88MB/s]
# Extracting files...
# Path to dataset files: /Users/kish/.cache/kagglehub/datasets/dylanjcastillo/7k-books-with-metadata/versions/3

# %% [markdown]
# ### Step 2: Navigate to directory where dataset files werre downloaded.
# 1. Command: cd /path/to/dataset/directory
# 2. Command: ls
#
# To view the files have been downloaded correctly.

# %%
import pandas as pd
books = pd.read_csv(f"{path}/books.csv")

# %%
books
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %% [markdown]
# ### Step 3: Perform exploratory data analysis (EDA)
#
# In the video they just use Pycharms inbuilt features to inspect the data.
# But I have written some code to get relevant descriptive statistics.
#
# #### Here are the steps I followed:
# 1. Load the dataset
#
# 2. Check for missing values
#
# 3. Get summary statistics
#
# 4. Visualize key distributions

# %%
#!pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
books = pd.read_csv(f"{path}/books.csv")  # Update this with the actual file path

# Display basic information about the dataset
print("Dataset Info:")
print(books.info())

# Show the first few rows
print("\nFirst 5 rows of the dataset:")
print(books.head())

# Check for missing values
print("\nMissing Values:")
print(books.isnull().sum())

# Get summary statistics
print("\nDescriptive Statistics:")
print(books.describe(include="all"))

# Visualizing distributions
plt.figure(figsize=(12, 6))
sns.histplot(books["average_rating"], bins=20, kde=True)
plt.title("Distribution of Ratings")
plt.xlabel("Average Rating")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12, 6))
sns.histplot(books["num_pages"].dropna(), bins=30, kde=True)
plt.title("Distribution of Number of Pages")
plt.xlabel("Number of Pages")
plt.ylabel("Count")
plt.show()

# Count of books per genre (if genre column exists)
if "genre" in books.columns:
    plt.figure(figsize=(12, 6))
    books["genre"].value_counts().nlargest(10).plot(kind="bar")
    plt.title("Top 10 Most Common Genres")
    plt.xlabel("Genre")
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6810 non-null   int64
#  1   isbn10          6810 non-null   object
#  2   title           6810 non-null   object
#  3   subtitle        2381 non-null   object
#  4   authors         6738 non-null   object
#  5   categories      6711 non-null   object
#  6   thumbnail       6481 non-null   object
#  7   description     6548 non-null   object
#  8   published_year  6804 non-null   float64
#  9   average_rating  6767 non-null   float64
#  10  num_pages       6767 non-null   float64
#  11  ratings_count   6767 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 638.6+ KB
# None
#
# First 5 rows of the dataset:
# ...

# %% [markdown]
# ### Key Insights from the Dataset:
# #### 1. General Overview
# The dataset contains 6,810 books with 12 attributes such as title, authors, categories, average_rating, num_pages, etc.
#
# Some columns have missing values, which might require handling before model training.
#
# #### 2. Missing Values
#
# | Column          | Missing Values | % Missing       |
# |----------------|---------------|----------------|
# | subtitle       | 4,429         | 65% (very high) |
# | authors        | 72            | 1.06%          |
# | categories     | 99            | 1.45%          |
# | thumbnail      | 329           | 4.83%          |
# | description    | 262           | 3.85%          |
# | published_year | 6             | 0.08%          |
# | average_rating | 43            | 0.63%          |
# | num_pages      | 43            | 0.63%          |
# | ratings_count  | 43            | 0.63%          |
#
# subtitle is missing for 65% of the books, meaning it may not be a reliable feature.
#
# Other missing values are minimal (<5%) and can be handled via imputation or removal.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = plt.axes()
sns.heatmap(books.isna().transpose(), cbar=False, ax=ax)

plt.xlabel("Colums")
plt.ylabel("Missing Values")

plt.show()

# %% [markdown]
#  - It is important to check whether missing values have a pattern because this can imply some sort of bias.
#  - Subtitles can be discarded as it has most missing values. Authors, categories, thumbnail, description, and published_year have random missing values.
#  - But average_rating, num_pages, and ratings_count have missing values in a similar pattern. This may be a source of bias in the dataset.

# %%
import numpy as np

books["missing_description"] = np.where(books["description"].isna(), 1, 0)
books["age_of_book"] = 2025 - books["published_year"]

# %%
columns_of_interest = ["num_pages", "age_of_book", "missing_description", "average_rating"]

correlation_matrix = books[columns_of_interest].corr(method="spearman") # Spearman correlation is more suitable for non continuous values    

sns.set_theme(style="white")
plt.figure(figsize=(4,4))
heatmap =sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar_kws={"label": "Spearman Correlation"})

heatmap.set_title("Correlation Heatmap")
plt.show()

# %% [markdown]
#  - What we are interested in here is the correlation of missing_description with other variables.
#  - For example, if correlation between missing_description and num_pages is high, it would indicate that either longer books or shorter books have more missing descriptions.
#  - And we are not going to use missing_description in our model, so the recommender can be biased towards longer or shorter books. Same for age_of_book and average_rating.
#  - But as we can see in the heatmap, these values are not very strong related to missing_description. (A value of 1 or -1 indicates a perfect positive or negative correlation, while a value closer to 0 indicates no correlation.)

# %%
books[(books["description"].isna()) |
    (books["num_pages"].isna()) |
    (books["average_rating"].isna()) |
    (books["published_year"].isna())
]
# Out:
#              isbn13      isbn10  \
# 37    9780006906018  000690601X
# 60    9780007127740  000712774X
# 99    9780020442806  0020442807
# 102   9780023513206  0023513209
# 105   9780026995016  0026995018
# ...             ...         ...
# 6787  9783464371640  3464371646
# 6788  9783540292128  3540292128
# 6798  9787506435673  7506435675
# 6806  9788185944609  8185944601
# 6807  9788445074879  8445074873
#
#                                                   title  \
# 37                    The Princess of the Chalet School
# 60                                  The illustrated man
# 99    The Chronicles of Narnia: Lion, the witch and ...
# 102                                   Reason in History
# 105                                             Spandau
# ...                                                 ...
# 6787                                        About a Boy
# 6788             Enzyme-Catalyzed Synthesis of Polymers
# 6798                                         Good Fight
# ...

# %% [markdown]
# - We will be only losing 303 rows, which is under 5% considering the dataset we have so we can go ahead and remove these rows.

# %%
book_missing = books[~(books["description"].isna()) &
    ~(books["num_pages"].isna()) &
    ~(books["average_rating"].isna()) &
    ~(books["published_year"].isna())
]

book_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6507 entries, 0 to 6809
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   isbn13               6507 non-null   int64
#  1   isbn10               6507 non-null   object
#  2   title                6507 non-null   object
#  3   subtitle             2281 non-null   object
#  4   authors              6444 non-null   object
#  5   categories           6474 non-null   object
#  6   thumbnail            6293 non-null   object
#  7   description          6507 non-null   object
#  8   published_year       6507 non-null   float64
#  9   average_rating       6507 non-null   float64
#  10  num_pages            6507 non-null   float64
#  11  ratings_count        6507 non-null   float64
#  12  missing_description  6507 non-null   int64
#  13  age_of_book          6507 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 762.5+ KB

# %% [markdown]
#  ### Step 4: Cleaning Data
#
#  #### Step 4.1 Cleaning Categories
#    - Categories is a mess.
#    - There are some categories which are way too specific and some which are way too general.
#    - We will group them into broader categories.

# %%
book_missing["categories"].value_counts().reset_index().sort_values("count", ascending=False)
# Out:
#                     categories  count
# 0                      Fiction   2523
# 1             Juvenile Fiction    534
# 2    Biography & Autobiography    391
# 3                      History    258
# 4           Literary Criticism    164
# ..                         ...    ...
# 280                    Butlers      1
# 279                    Gardens      1
# 278                  Assassins      1
# 277             Married people      1
# 530    Indic fiction (English)      1
#
# [531 rows x 2 columns]

# %%
# Get category counts
category_counts = book_missing["categories"].value_counts().reset_index()
category_counts.columns = ["Category", "Count"]  # Rename columns
category_counts = category_counts.sort_values("Count", ascending=False)  # Sort in descending order

# Plot the bar chart
plt.figure(figsize=(60, 8))  # Increase figure size for readability
sns.barplot(data=category_counts, x="Category", y="Count", palette="viridis")

plt.xticks(rotation=90, ha="right")  # Rotate x-axis labels for better readability
plt.xlabel("Book Categories")
plt.ylabel("Number of Books")
plt.title("Book Counts by Category")
plt.tight_layout()  # Adjust layout to prevent label cutoff

plt.show()
# Out:
# /var/folders/sl/2wqqlz2j3m9f1gyr2xn155m80000gn/T/ipykernel_90411/516601540.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=category_counts, x="Category", y="Count", palette="viridis")

# %% [markdown]
# #### Step 4.2: Removing short descriptions.
# - Short descriptions are not very helpful.
# - It has to be meaningful so that we can recommend it.
# - Easiest way to check this is to check the length of the description.
# - So we will create a new variable words_in_description. We will take description and split it into words, then count the number of words.

# %%
book_missing["words_in_description"] = book_missing["description"].str.split().str.len()
book_missing
# Out:
# /var/folders/sl/2wqqlz2j3m9f1gyr2xn155m80000gn/T/ipykernel_90411/1407513420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_missing["words_in_description"] = book_missing["description"].str.split().str.len()
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# ...

# %%
# Plot histogram
plt.figure(figsize=(12, 6))
sns.histplot(book_missing["words_in_description"], bins=range(0, book_missing["words_in_description"].max() + 5, 5), kde=False, color="blue")

# Labels and title
plt.xlabel("Word Count in Description (Binned)")
plt.ylabel("Number of Books")
plt.title("Histogram of Word Counts in Book Descriptions")

# Show plot
plt.show()

# %%
book_missing.loc[book_missing["words_in_description"].between(1,4), "description"]
# Out:
# 6                                           Donation.
# 11                                     Fantasy-roman.
# 748              Includes bibliographical references.
# 770                             Bound For Oregon (PB)
# 775                                No Marketing Blurb
# 812                                No Marketing Blurb
# 857                          First published in 1813.
# 944                         Edited by Maurice Hindle.
# 953                        DEFOE/ROBINSON CRUSOE (BC)
# 954                             Edited by John Carey.
# 962                         ALLEN/GETTING THINGS DONE
# 1054                            GILBERT/EAT PRAY LOVE
# 1056    "Graham Greene centennial, 1904-2004"--Cover.
# 1060                   STEINBECK/GRAPES OF WRATH (BC)
# 1346                                   Fantasy-roman.
# 1546                                      Winter 2003
# 1610                                      Winter 1999
# ...

# %%
book_missing.loc[book_missing["words_in_description"].between(5,14), "description"]
# Out:
# 2       Volume Two of Stephen Donaldson's acclaimed se...
# 38      Koko is Peter Straub's foray into the psycholo...
# 70      A matter of life and death - and the Throne of...
# 77                         Nonsense rhyming story. 4 yrs+
# 84      A study guide for the novel There's a Boy in t...
#                               ...
# 6715    The first comprehensive guide to addressing Na...
# 6726       Presents two complete novels from Henry James.
# 6757                          Audio Book- unabriged on CD
# 6776    Raymond Chandler meets The Exorcist. Classic n...
# 6795    Book Of Five Rings is a Kodansha International...
# Name: description, Length: 308, dtype: object

# %%
book_missing.loc[book_missing["words_in_description"].between(15,24), "description"]
# Out:
# 10      One of Sidney Sheldon's most popular and bests...
# 32      Tells the story of three generations of Chines...
# 36      A magical and fantastic collection of early st...
# 57      A young drifter finds more than he bargained f...
# 68      A new 'The Doors of Perception' for the 21st c...
#                               ...
# 6767    Everything from the fingerprints of the gods t...
# 6782    Displays one of America's leading physicist's ...
# 6783    Basics Illustration 01: Thinking Visually expl...
# 6789    Provides an introduction to the American artis...
# 6809    This is a jubilant and rewarding collection of...
# Name: description, Length: 947, dtype: object

# %%
book_missing.loc[book_missing["words_in_description"].between(25,34), "description"]
# Out:
# 9       Kate Blackwell is an enigma and one of the mos...
# 14      Available in the U.S. for the first time, this...
# 20      It is 1937, and Charles Ashworth, a Canon to t...
# 21      Reissue of the author's most famous and well-l...
# 46      No one believes a little girl when she insists...
#                               ...
# 6760    Joel, an English teacher, has never really lik...
# 6766    Discusses the historical and intellectual back...
# 6775    Presents nearly one thousand recipes--from app...
# 6779    Edited by the creator and executive producer o...
# 6799    This book is the story of a young girl obsesse...
# Name: description, Length: 1229, dtype: object

# %% [markdown]
# - The cutoff will be 25 words in description to remove short descriptions. But we lost a lot of data.

# %%
book_missing_25_words = book_missing[book_missing["words_in_description"] >= 25]
book_missing_25_words.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5197 entries, 0 to 6808
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   isbn13                5197 non-null   int64
#  1   isbn10                5197 non-null   object
#  2   title                 5197 non-null   object
#  3   subtitle              1817 non-null   object
#  4   authors               5165 non-null   object
#  5   categories            5167 non-null   object
#  6   thumbnail             5031 non-null   object
#  7   description           5197 non-null   object
#  8   published_year        5197 non-null   float64
#  9   average_rating        5197 non-null   float64
#  10  num_pages             5197 non-null   float64
#  11  ratings_count         5197 non-null   float64
#  12  missing_description   5197 non-null   int64
#  13  age_of_book           5197 non-null   float64
#  14  words_in_description  5197 non-null   int64
# ...

# %% [markdown]
# #### Step 4.3: Combine title and subtitle to create a new column title_and_subtitle

# %%
book_missing_25_words["title_and_subtitle"] = (np.where(book_missing_25_words["subtitle"].isna(), 
                                                        book_missing_25_words["title"], 
                                                        book_missing_25_words[["title", "subtitle"]].astype(str).agg(": ".join, axis=1)))

book_missing_25_words.head()
# Out:
# /var/folders/sl/2wqqlz2j3m9f1gyr2xn155m80000gn/T/ipykernel_90411/2993952849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_missing_25_words["title_and_subtitle"] = (np.where(book_missing_25_words["subtitle"].isna(),
#           isbn13      isbn10                title subtitle  \
# 0  9780002005883  0002005883               Gilead      NaN
# 1  9780002261982  0002261987         Spider's Web  A Novel
# 3  9780006178736  0006178731       Rage of angels      NaN
# 4  9780006280897  0006280897       The Four Loves      NaN
# 5  9780006280934  0006280935  The Problem of Pain      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# ...

# %%
book_missing_25_words["tagged_description"] = book_missing_25_words[["isbn13", "description"]].astype(str).agg(" ".join, axis=1)
book_missing_25_words.head()
# Out:
# /var/folders/sl/2wqqlz2j3m9f1gyr2xn155m80000gn/T/ipykernel_90411/3860166687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_missing_25_words["tagged_description"] = book_missing_25_words[["isbn13", "description"]].astype(str).agg(" ".join, axis=1)
#           isbn13      isbn10                title subtitle  \
# 0  9780002005883  0002005883               Gilead      NaN
# 1  9780002261982  0002261987         Spider's Web  A Novel
# 3  9780006178736  0006178731       Rage of angels      NaN
# 4  9780006280897  0006280897       The Four Loves      NaN
# 5  9780006280934  0006280935  The Problem of Pain      NaN
#
#                            authors                     categories  \
# ...

# %% [markdown]
# #### Step 4.4: Drop unnecessary columns

# %%
(
    book_missing_25_words
    .drop(["subtitle", "missing_description", "words_in_description", "age_of_book"], axis=1)
    .to_csv("books_cleaned.csv", index=False)
)
